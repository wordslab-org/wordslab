# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
rootdir = Path("/mnt/d/Laurent/nlptextdoc-data-201909")
websitesdf = pd.read_csv(rootdir / "_nlptextdoc" / "websites.csv",sep=';')

# %%
def getdataframes(websitedir):
    textdffile = websitedir / "_nlptextdoc" / "nlptextdocs.dataframe.feather"
    urlsdffile = websitedir / "_nlptextdoc" / "urls.dataframe.feather"
    if(textdffile.exists()):
        return (pd.read_feather(urlsdffile),pd.read_feather(textdffile))
    else:
        return (None,None)

# %%
websitedir = Path(r"D:\Laurent\nlptextdoc-data-201909\www.service-public.fr".replace("\\","/").replace("D:","/mnt/d"))
urlsdf,textdf = getdataframes(websitedir)

# %%
len(urlsdf),len(textdf)
# Out:
# (5702, 4650146)

# %%
from fasttext import FastText

langmodel = FastText.load_model("models/lid.176.bin")
langlabels = langmodel.get_labels()
langcodes = {val:val[-2:] for val in langlabels}

def getlanguage(text):
    pred = langmodel.predict(text)
    return (langcodes[pred[0][0]],pred[1][0])

# %%
import spacy

nlp = spacy.load("fr_core_news_sm",disable=["tagger","ner","parser"])

# %%
def add_lang_words_to_dataframes(websitedir):
    textdffile = websitedir / "_nlptextdoc" / "nlptextdocs.dataframe.feather"
    if(textdffile.exists()):
        textdf = pd.read_feather(textdffile)
        if("Lang" in textdf.columns):
            return textdf
        listLanguages = []
        listWordCounts = []
        for rowidx,row in textdf.iterrows():
            if (((row["DocEltType"] != "Document") or (row["DocEltCmd"] == "Title")) and (row["DocEltCmd"] != "End") and not (row["Text"] is None)):
                text = row["Text"]
                wordCount = len(nlp(text))
                listWordCounts.append(wordCount)
                textforlang = text.replace('\n',' ')
                lang,prob = getlanguage(textforlang)
                if(prob > 0.6):
                    listLanguages.append(lang)
                else:
                    listLanguages.append("?")
            else:
                listWordCounts.append(0)
                listLanguages.append(None)        
        textdf["Lang"] = listLanguages
        textdf["Words"] = listWordCounts
        textdf = textdf.astype({"Lang" : "category", "Words": np.uint16},copy=False)
        textdf.to_feather(textdffile)
        return textdf
    else:
        return None

# %%
textdf = add_lang_words_to_dataframes(websitedir)

# %%
textdf.head(20)
# Out:
#     DocId DocEltType DocEltCmd  NestingLevel  \
# 0       1   Document     Start             1
# 1       1   Document     Title             1
# 2       1   Document       Uri             1
# 3       1       List     Start             1
# 4       1   ListItem      Text             2
# 5       1   ListItem      Text             2
# 6       1   ListItem      Text             2
# 7       1       List       End             1
# 8       1  TextBlock      Text             1
# 9       1    Section     Start             1
# 10      1    Section       End             1
# 11      1  TextBlock      Text             1
# 12      1  TextBlock      Text             1
# 13      1  TextBlock      Text             1
# 14      1  TextBlock      Text             1
# 15      1  TextBlock      Text             1
# 16      1  TextBlock      Text             1
# 17      1  TextBlock      Text             1
# 18      1  TextBlock      Text             1
# 19      1  TextBlock      Text             1
#
#                                                  Text Lang  Words
# 0                                                   1  NaN      0
# 1           À propos de nous | 10MeilleuresBanques.fr   fr      6
# 2            https://www.10meilleuresbanques.fr/about  NaN      0
# 3                                                None  NaN      0
# 4                                          Classement   fr      1
# 5                                          Évaluation   fr      1
# 6                                        Plus d'infos   fr      3
# 7                                                None  NaN      0
# 8                                        Home > About    ?      3
# 9                                    À propos de nous   fr      4
# 10                                               None  NaN      0
# 11                                                  ​   km      1
# 12                                   À propos de nous   fr      4
# 13  Créé pour nous aider à choisir parmi une multi...   fr     53
# 14  Vous avez trouvé ce site utile? Vous avez des ...   fr     16
# 15  Pour les questions d’ordre générale commentair...   fr     20
# 16  Pour toutes questions reliées à notre entrepri...   fr     23
# 17  Pour nous faire parvenir un courrier , écrivez...   fr     24
# 18                                     Contactez-nous   fr      3
# 19  Copyright © 2009-2019 Natural Intelligence Ltd...   fr     61

# %%
for idx,row in websitesdf.iterrows():
    websitedir = Path(row[3].replace("\\","/").replace("D:","/mnt/d"))
    websiteurl = row[1]
    add_lang_words_to_dataframes(websitedir)
    print(f"Enhanced {websiteurl}")
# Out:
# Enhanced https://www.10meilleuresbanques.fr/
# Enhanced https://www.abcbourse.com/
# Enhanced https://acpr.banque-france.fr/
# Enhanced https://www.afer.fr/
# Enhanced https://www.ag2rlamondiale.fr/
# Enhanced https://www.agpm.fr/
# Enhanced https://www.amaguiz.com/
# Enhanced https://www.arkea.com/
# Enhanced https://www.assurland.com/
# Enhanced https://www.aviva.fr/
# Enhanced https://www.axa.fr/
# Enhanced https://www.banque-edel.fr/
# Enhanced https://www.banque-france.fr/
# Enhanced http://www.banque-info.com/
# Enhanced https://www.banque.fr/
# Enhanced https://www.banquepopulaire.fr/
# Enhanced https://www.banquesenligne.org/
# Enhanced https://www.bforbank.com/
# Enhanced https://www.boursedeparis.fr/
# Enhanced http://www.boursedirect.fr/
# Enhanced https://www.boursier.com/
# Enhanced https://www.boursorama-banque.com/
# Enhanced https://www.boursorama.com/
# Enhanced https://www.bred.fr/
# Enhanced https://www.ca-alsace-vosges.fr/
# Enhanced http://www.capitaine-epargne.com/
# Enhanced http://cercledelepargne.com/
# Enhanced https://www.cetelem.fr/
# Enhanced https://www.cic.fr/
# Enhanced https://www.cnp.fr/
# Enhanced https://www.cofidis.fr/
# Enhanced https://www.cofinoga.fr/
# Enhanced http://www.comparabanques.fr/
# Enhanced http://www.comparalivrets.fr/
# Enhanced https://compte-nickel.fr/
# Enhanced https://www.credit-cooperatif.coop/
# Enhanced https://www.credit-du-nord.fr/
# Enhanced https://www.creditmutuel.fr/
# Enhanced https://www.culturebanque.com/
# Enhanced https://www.diac.fr/
# Enhanced https://www.direct-assurance.fr/
# Enhanced https://droit-finances.commentcamarche.com/
# Enhanced https://eko-by-ca.fr/
# Enhanced https://www.empruntis.com/
# Enhanced https://www.en-bourse.fr/
# Enhanced https://www.eurofil.com/
# Enhanced https://www.ffa-assurance.fr/
# Enhanced https://www.fortuneo.fr/
# Enhanced http://forum.doctissimo.fr/famille/argent-budget-famille/liste_sujet-1.htm
# Enhanced http://forum.doctissimo.fr/viepratique/finances/liste_sujet-1.htm
# Enhanced http://forum.doctissimo.fr/viepratique/Impots/liste_sujet-1.htm
# Enhanced https://forum.lesarnaques.com/assurance-automobile/
# Enhanced https://forum.lesarnaques.com/banque/
# Enhanced https://fr.finance.yahoo.com/
# Enhanced https://fr.wikipedia.org/wiki/Finance
# Enhanced https://www.francetransactions.com/
# Enhanced http://www.generali.fr/
# Enhanced https://www.groupama.fr/
# Enhanced http://www.guide-epargne.com/
# Enhanced https://www.hellobank.fr/
# Enhanced https://www.hsbc.fr/
# Enhanced https://www.ing.fr/banque-en-ligne/
# Enhanced https://www.labanquepostale.fr/
# Enhanced http://labourseauquotidien.fr/
# Enhanced https://www.latribune.fr/
# Enhanced https://www.lcl.fr/
# Enhanced https://www.lelynx.fr/
# Enhanced https://www.lesclesdelabanque.com/Web/Cdb/Particuliers/Content.nsf/List_HTML_Lexique?ReadForm&Count=-1&VirtualCategory=6TECRZ
# Enhanced https://www.lesfurets.com/
# Enhanced https://www.lolivier.fr/
# Enhanced https://mabanque.bnpparibas/
# Enhanced https://www.mae.fr/
# Enhanced http://www.malakoffmederic.com/
# Enhanced https://www.matmut.fr/
# Enhanced https://banque.meilleurtaux.com/
# Enhanced https://mes-placements.fr/
# Enhanced https://www.mma.fr/
# Enhanced https://www.mon-epargne.com/
# Enhanced https://www.monabanq.com/fr/index.html
# Enhanced https://n26.com/fr-fr/
# Enhanced https://www.natixis.com/natixis/jcms/j_6/fr/accueil
# Enhanced https://www.oney.fr/
# Enhanced https://epargne.ooreka.fr/
# Enhanced https://www.orangebank.fr/
# Enhanced https://www.palatine.fr/
# Enhanced https://www.panorabanques.com/
# Enhanced https://www.probtp.com/
# Enhanced https://www.psabanque.fr/
# Enhanced https://www.quechoisir.org/thematique-banque-credit-t111/
# Enhanced http://www.retraiteepargne.fr/
# Enhanced http://www.revue-banque.fr/
# Enhanced https://www.smc.fr/
# Enhanced https://www.societegenerale.fr/
# Enhanced https://www.sofinco.fr/
# Enhanced https://www.strategie-bourse.com/
# Enhanced https://www.toutsurmesfinances.com/
# Enhanced https://www.tradingsat.com/
# Enhanced https://www.usine-digitale.fr/banque/
# Enhanced https://dumps.wikimedia.org/frwiki/latest/100000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/200000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/300000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/400000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/500000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/515431
# Enhanced https://www.60millions-mag.com/forum/
# Enhanced https://www.allianz.fr/
# Enhanced https://www.allianzbanque.fr/a/z/b/jm_6268/fr/navigations
# Enhanced https://www.ameli.fr/
# Enhanced https://www.amundi.fr/fr_part
# Enhanced http://www.assurances.com/
# Enhanced http://www.banque.org/
# Enhanced https://www.boursorama.com/patrimoine/forum/
# Enhanced https://www.caisse-epargne.fr/
# Enhanced https://www.cbanque.com/
# Enhanced https://www.cbanque.com/forums/
# Enhanced https://www.challenges.fr/tag_theme/banque_876/

# %%
from hashlib import md5

def add_hash_to_dataframes(websitedir):
    textdffile = websitedir / "_nlptextdoc" / "nlptextdocs.dataframe.feather"
    if(textdffile.exists()):
        textdf = pd.read_feather(textdffile)
        if("Hash" in textdf.columns):
            return textdf
        listHashes = []
        for rowidx,row in textdf.iterrows():
            if (((row["DocEltType"] != "Document") or (row["DocEltCmd"] == "Title")) and (row["DocEltCmd"] != "End") and not (row["Text"] is None)):
                text = row["Text"]
                hval = md5(text.encode()).digest()
                listHashes.append(hval)
            else:
                listHashes.append(None)        
        textdf["Hash"] = listHashes
        textdf.to_feather(textdffile)
        return textdf
    else:
        return None

# %%
textdf = add_hash_to_dataframes(websitedir)

# %%
textdf.head(20)
# Out:
#     DocId DocEltType DocEltCmd  NestingLevel  \
# 0       1   Document     Start             1
# 1       1   Document     Title             1
# 2       1   Document       Uri             1
# 3       1       List     Start             1
# 4       1   ListItem      Text             2
# 5       1   ListItem      Text             2
# 6       1   ListItem      Text             2
# 7       1       List       End             1
# 8       1  TextBlock      Text             1
# 9       1    Section     Start             1
# 10      1    Section       End             1
# 11      1  TextBlock      Text             1
# 12      1  TextBlock      Text             1
# 13      1  TextBlock      Text             1
# 14      1  TextBlock      Text             1
# 15      1  TextBlock      Text             1
# 16      1  TextBlock      Text             1
# 17      1  TextBlock      Text             1
# 18      1  TextBlock      Text             1
# 19      1  TextBlock      Text             1
#
#                                                  Text Lang  Words  \
# 0                                                   1  NaN      0
# 1           À propos de nous | 10MeilleuresBanques.fr   fr      6
# 2            https://www.10meilleuresbanques.fr/about  NaN      0
# 3                                                None  NaN      0
# 4                                          Classement   fr      1
# 5                                          Évaluation   fr      1
# 6                                        Plus d'infos   fr      3
# 7                                                None  NaN      0
# 8                                        Home > About    ?      3
# 9                                    À propos de nous   fr      4
# 10                                               None  NaN      0
# 11                                                  ​   km      1
# 12                                   À propos de nous   fr      4
# 13  Créé pour nous aider à choisir parmi une multi...   fr     53
# 14  Vous avez trouvé ce site utile? Vous avez des ...   fr     16
# 15  Pour les questions d’ordre générale commentair...   fr     20
# 16  Pour toutes questions reliées à notre entrepri...   fr     23
# 17  Pour nous faire parvenir un courrier , écrivez...   fr     24
# 18                                     Contactez-nous   fr      3
# 19  Copyright © 2009-2019 Natural Intelligence Ltd...   fr     61
#
#                                                  Hash
# 0                                                None
# 1   b'\x8e\xf7\x00hN\xc2+ \x9f\xe7F\x91\xdc\xcd\xb...
# 2                                                None
# 3                                                None
# 4   b'\x8b\xf7\xf9\x1d\x96\xf4\xc0t\xe2s\x95\x18\x...
# 5        b'R\xc2W.\x01\\\xeb\xe3v\x04(\x16!\xad>\xca'
# 6      b'\x7f\xef\xdd\x90\x88xP!eHE\xd4\xf5u\x8a\xa3'
# 7                                                None
# 8        b'P\xb5TM\x99\xd2\x8b\xc1\xac#Kg\x17U\x02\\'
# 9   b'#\xcf\x81\x8f\xf5g\xdd\x84\xbb\x8e\x95\x19\x...
# 10                                               None
# 11           b'\xd0J\x07\xd8\x9c\xd1b9\x11I \x81=lg;'
# 12  b'#\xcf\x81\x8f\xf5g\xdd\x84\xbb\x8e\x95\x19\x...
# 13  b'\xaf\xe1I\xbd\xa1\x02\x9dv$\xb9\x80\x0f\x9aF**'
# 14     b"nT\xbc\x12m'\x84t\xbd\xea\xa5}$\x08\x1c\x1f"
# 15  b'\xf3\x1fu\xa4\xdbV\xb2\x9f\xe7\xe9%g.\x89W\x0e'
# 16       b'0O\x90\xc55M\xb4 G\xe2\x97\x90g\xae\xbd\t'
# 17        b'\x1aI\xd2\xee\xeaN277\x1c\xad\xe6Ew@\xeb'
# 18        b'6\xf0 X\x05Wy\xbe<b\xde\xde\xde\xado\xa1'
# 19    b'\xf3a\x90\xc9\x88\x00L\x86u\xc8c7\t\xf7\x89+'

# %%
import pandas as pd
from hashlib import md5

def add_unique_to_dataframes(websitedir):
    textdffile = websitedir / "_nlptextdoc" / "nlptextdocs.dataframe.feather"
    if(textdffile.exists()):
        textdf = pd.read_feather(textdffile)
        if("Unique" in textdf.columns):
            return textdf
        if(not ("Lang" in textdf.columns)):
            print("Dataframe not ready with Lang and Words")
            return None
        listUnique = []
        hashes = set()
        for rowidx,row in textdf.iterrows():
            if (((row["DocEltType"] != "Document") or (row["DocEltCmd"] == "Title")) and (row["DocEltCmd"] != "End") and not (row["Text"] is None)):
                text = row["Text"]
                hval = md5(text.encode()).digest()
                if not (hval in hashes):         
                    hashes.add(hval)
                    listUnique.append(True)
                else:
                    listUnique.append(False)
            else:
                listUnique.append(None)
        textdf["Unique"] = listUnique
        textdf.to_feather(websitedir / "_nlptextdoc" / "nlptextdocs.dataframe.feather")
        return textdf
    else:
        return None

# %%
textdf = add_unique_to_dataframes(websitedir)
textdf.head(50)
# Out:
#     DocId      DocEltType DocEltCmd  NestingLevel  \
# 0       1        Document     Start             1
# 1       1        Document     Title             1
# 2       1        Document       Uri             1
# 3       1  NavigationList     Start             1
# 4       1        ListItem      Text             2
# 5       1        ListItem      Text             2
# 6       1        ListItem      Text             2
# 7       1  NavigationList       End             1
# 8       1  NavigationList     Start             1
# 9       1        ListItem      Text             2
# 10      1        ListItem      Text             2
# 11      1        ListItem      Text             2
# 12      1        ListItem      Text             2
# 13      1        ListItem      Text             2
# 14      1        ListItem      Text             2
# 15      1  NavigationList       End             1
# 16      1       TextBlock      Text             1
# 17      1       TextBlock      Text             1
# 18      1  NavigationList     Start             1
# 19      1        ListItem      Text             2
# 20      1        ListItem      Text             2
# 21      1  NavigationList       End             1
# 22      1       TextBlock      Text             1
# 23      1  NavigationList     Start             1
# 24      1        ListItem      Text             2
# 25      1        ListItem      Text             2
# 26      1        ListItem      Text             2
# 27      1  NavigationList       End             1
# 28      1       TextBlock      Text             1
# 29      1  NavigationList     Start             1
# 30      1        ListItem      Text             2
# 31      1        ListItem      Text             2
# 32      1        ListItem      Text             2
# 33      1        ListItem      Text             2
# 34      1        ListItem      Text             2
# 35      1  NavigationList       End             1
# 36      1            List     Start             1
# 37      1        ListItem     Start             2
# 38      1       TextBlock      Text             2
# 39      1        ListItem       End             2
# 40      1        ListItem     Start             2
# 41      1       TextBlock      Text             2
# 42      1       TextBlock      Text             2
# 43      1  NavigationList     Start             3
# 44      1        ListItem      Text             4
# 45      1        ListItem      Text             4
# 46      1  NavigationList       End             3
# 47      1       TextBlock      Text             3
# 48      1        ListItem       End             2
# 49      1        ListItem     Start             2
#
#                                                  Text Lang  Words Unique
# 0                                                   1  NaN      0   None
# 1            Accueil Associations | service-public.fr    ?      4   True
# 2          https://www.service-public.fr/associations  NaN      0   None
# 3                                                None  NaN      0   None
# 4                                    Aller au contenu   fr      3   True
# 5                                Aller à la recherche   fr      4   True
# 6                       Aller au menu de Associations   fr      5   True
# 7                                                None  NaN      0   None
# 8                                                None  NaN      0   None
# 9                                                menu    ?      1   True
# 10                                       Particuliers    ?      1   True
# 11                                    Pro fessionnels   fr      2   True
# 12                                      Asso ciations   en      2   True
# 13                       Annuaire de l’administration    ?      4   True
# 14                                       Se connecter    ?      2   True
# 15                                               None  NaN      0   None
# 16                                             Fermer    ?      1   True
# 17                     Accueil Service-Public-Asso.fr    ?      6   True
# 18                                               None  NaN      0   None
# 19                                     Une question ?   fr      3   True
# 20                   Services en ligne et formulaires   fr      5   True
# 21                                               None  NaN      0   None
# 22                                             Fermer    ?      1  False
# 23                                               None  NaN      0   None
# 24                                       Se connecter    ?      2  False
# 25                                     Une question ?   fr      3  False
# 26                   Services en ligne et formulaires   fr      5  False
# 27                                               None  NaN      0   None
# 28                                       Associations    ?      1   True
# 29                                               None  NaN      0   None
# 30       Formalités administratives d’une association   fr      5   True
# 31                   Fonctionnement d’une association   fr      4   True
# 32         Financement et fiscalité d’une association   fr      6   True
# 33             Associations spécifiques et fondations   fr      4   True
# 34                                         Actualités   fr      1   True
# 35                                               None  NaN      0   None
# 36                                               None  NaN      0   None
# 37                                               None  NaN      0   None
# 38                                    Accueil - actif   fr      3   True
# 39                                               None  NaN      0   None
# 40                                               None  NaN      0   None
# 41       Formalités administratives d’une association   fr      5  False
# 42                                             Fermer    ?      1  False
# 43                                               None  NaN      0   None
# 44                                           Création   fr      1   True
# 45                                         Évolutions    ?      1   True
# 46                                               None  NaN      0   None
# 47  Afficher le thème Formalités administratives d...   fr      8   True
# 48                                               None  NaN      0   None
# 49                                               None  NaN      0   None

# %%
for idx,row in websitesdf.iterrows():
    websitedir = Path(row[3].replace("\\","/").replace("D:","/mnt/d"))
    websiteurl = row[1]
    add_unique_to_dataframes(websitedir)
    print(f"Enhanced {websiteurl}")
# Out:
# Enhanced https://www.10meilleuresbanques.fr/
# Enhanced https://www.abcbourse.com/
# Enhanced https://acpr.banque-france.fr/
# Enhanced https://www.afer.fr/
# Enhanced https://www.ag2rlamondiale.fr/
# Enhanced https://www.agpm.fr/
# Enhanced https://www.amaguiz.com/
# Enhanced https://www.arkea.com/
# Enhanced https://www.assurland.com/
# Enhanced https://www.aviva.fr/
# Enhanced https://www.axa.fr/
# Enhanced https://www.banque-edel.fr/
# Enhanced https://www.banque-france.fr/
# Enhanced http://www.banque-info.com/
# Enhanced https://www.banque.fr/
# Enhanced https://www.banquepopulaire.fr/
# Enhanced https://www.banquesenligne.org/
# Enhanced https://www.bforbank.com/
# Enhanced https://www.boursedeparis.fr/
# Enhanced http://www.boursedirect.fr/
# Enhanced https://www.boursier.com/
# Enhanced https://www.boursorama-banque.com/
# Enhanced https://www.boursorama.com/
# Enhanced https://www.bred.fr/
# Enhanced https://www.ca-alsace-vosges.fr/
# Enhanced http://www.capitaine-epargne.com/
# Enhanced http://cercledelepargne.com/
# Enhanced https://www.cetelem.fr/
# Enhanced https://www.cic.fr/
# Enhanced https://www.cnp.fr/
# Enhanced https://www.cofidis.fr/
# Enhanced https://www.cofinoga.fr/
# Enhanced http://www.comparabanques.fr/
# Enhanced http://www.comparalivrets.fr/
# Enhanced https://compte-nickel.fr/
# Enhanced https://www.credit-cooperatif.coop/
# Enhanced https://www.credit-du-nord.fr/
# Enhanced https://www.creditmutuel.fr/
# Enhanced https://www.culturebanque.com/
# Enhanced https://www.diac.fr/
# Enhanced https://www.direct-assurance.fr/
# Enhanced https://droit-finances.commentcamarche.com/
# Enhanced https://eko-by-ca.fr/
# Enhanced https://www.empruntis.com/
# Enhanced https://www.en-bourse.fr/
# Enhanced https://www.eurofil.com/
# Enhanced https://www.ffa-assurance.fr/
# Enhanced https://www.fortuneo.fr/
# Enhanced http://forum.doctissimo.fr/famille/argent-budget-famille/liste_sujet-1.htm
# Enhanced http://forum.doctissimo.fr/viepratique/finances/liste_sujet-1.htm
# Enhanced http://forum.doctissimo.fr/viepratique/Impots/liste_sujet-1.htm
# Enhanced https://forum.lesarnaques.com/assurance-automobile/
# Enhanced https://forum.lesarnaques.com/banque/
# Enhanced https://fr.finance.yahoo.com/
# Enhanced https://fr.wikipedia.org/wiki/Finance
# Enhanced https://www.francetransactions.com/
# Enhanced http://www.generali.fr/
# Enhanced https://www.groupama.fr/
# Enhanced http://www.guide-epargne.com/
# Enhanced https://www.hellobank.fr/
# Enhanced https://www.hsbc.fr/
# Enhanced https://www.ing.fr/banque-en-ligne/
# Enhanced https://www.labanquepostale.fr/
# Enhanced http://labourseauquotidien.fr/
# Enhanced https://www.latribune.fr/
# Enhanced https://www.lcl.fr/
# Enhanced https://www.lelynx.fr/
# Enhanced https://www.lesclesdelabanque.com/Web/Cdb/Particuliers/Content.nsf/List_HTML_Lexique?ReadForm&Count=-1&VirtualCategory=6TECRZ
# Enhanced https://www.lesfurets.com/
# Enhanced https://www.lolivier.fr/
# Enhanced https://mabanque.bnpparibas/
# Enhanced https://www.mae.fr/
# Enhanced http://www.malakoffmederic.com/
# Enhanced https://www.matmut.fr/
# Enhanced https://banque.meilleurtaux.com/
# Enhanced https://mes-placements.fr/
# Enhanced https://www.mma.fr/
# Enhanced https://www.mon-epargne.com/
# Enhanced https://www.monabanq.com/fr/index.html
# Enhanced https://n26.com/fr-fr/
# Enhanced https://www.natixis.com/natixis/jcms/j_6/fr/accueil
# Enhanced https://www.oney.fr/
# Enhanced https://epargne.ooreka.fr/
# Enhanced https://www.orangebank.fr/
# Enhanced https://www.palatine.fr/
# Enhanced https://www.panorabanques.com/
# Enhanced https://www.probtp.com/
# Enhanced https://www.psabanque.fr/
# Enhanced https://www.quechoisir.org/thematique-banque-credit-t111/
# Enhanced http://www.retraiteepargne.fr/
# Enhanced http://www.revue-banque.fr/
# Enhanced https://www.smc.fr/
# Enhanced https://www.societegenerale.fr/
# Enhanced https://www.sofinco.fr/
# Enhanced https://www.strategie-bourse.com/
# Enhanced https://www.toutsurmesfinances.com/
# Enhanced https://www.tradingsat.com/
# Enhanced https://www.usine-digitale.fr/banque/
# Enhanced https://dumps.wikimedia.org/frwiki/latest/100000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/200000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/300000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/400000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/500000
# Enhanced https://dumps.wikimedia.org/frwiki/latest/515431
# Enhanced https://www.60millions-mag.com/forum/
# Enhanced https://www.allianz.fr/
# Enhanced https://www.allianzbanque.fr/a/z/b/jm_6268/fr/navigations
# Enhanced https://www.ameli.fr/
# Enhanced https://www.amundi.fr/fr_part
# Enhanced http://www.assurances.com/
# Enhanced http://www.banque.org/
# Enhanced https://www.boursorama.com/patrimoine/forum/
# Enhanced https://www.caisse-epargne.fr/
# Enhanced https://www.cbanque.com/
# Enhanced https://www.cbanque.com/forums/
# Enhanced https://www.challenges.fr/tag_theme/banque_876/
# Enhanced https://www.challenges.fr/tag_theme/banque_876/100000
# Enhanced https://www.challenges.fr/tag_theme/banque_876/200000
# Enhanced https://www.challenges.fr/tag_theme/banque_876/300000
# Enhanced https://www.challenges.fr/tag_theme/banque_876/400000
# Enhanced https://www.credit-agricole.fr/
# Enhanced https://www.credit-et-banque.com/
# Enhanced https://www.creditfoncier.fr/
# Enhanced https://www.economie.gouv.fr/
# Enhanced https://www.gan.fr/
# Enhanced https://www.impots.gouv.fr/portail/
# Enhanced http://www.lefigaro.fr/economie
# Enhanced http://www.lemonde.fr/epargne/
# Enhanced http://www.leparisien.fr/economie/votre-argent/
# Enhanced https://www.lerevenu.com/
# Enhanced https://www.lesechos.fr/finance-marches/
# Enhanced https://www.lesechos.fr/finance-marches/100000
# Enhanced https://www.lesechos.fr/finance-marches/200000
# Enhanced https://www.lesechos.fr/finance-marches/300000
# Enhanced https://www.lesechos.fr/finance-marches/400000
# Enhanced https://www.lesechos.fr/finance-marches/500000
# Enhanced https://www.linternaute.com/argent/
# Enhanced https://www.maif.fr/
# Enhanced https://www.montepaschi-banque.fr/fr/
# Enhanced http://www.msn.com/fr-fr/finance
# Enhanced https://www.ouest-france.fr/economie/banques-finance/
# Enhanced https://www.revolut.com/fr-FR/
# Enhanced https://www.service-public.fr/particuliers/vosdroits/N19803
# Enhanced https://www.younited-credit.com/
# Enhanced https://www.zonebourse.com/

# %%
from urllib.parse import urlparse
from collections import Counter

names = []
subdirs = []
counter = Counter()
for idx,row in websitesdf.iterrows():
    subdir = row[3].split("\\")[-1:][0]
    subdirs.append(subdir)
    websiteurl = row[1]
    o = urlparse(websiteurl)
    domain = o.netloc.replace("www.","").replace(".fr","").replace(".org","").replace(".com","").replace(".coop","").replace(".","-")
    counter[domain] +=1
    name = domain if counter[domain]==1 else (domain + "-" + str(counter[domain])) 
    if(name == "banque"):
        name = "banque-fr"
    if(name == "banque-2"):
        name = "banque-org"
    if(name == "boursorama-2"):
        name = "boursorama-forum"
    if(name == "droit-financesmentcamarche"):
        name = "droit-finances-commentcamarche"
    if(name == "cbanque-2"):
        name = "cbanque-forum"
    if(name == "linternaute"):
        name = "linternaute-argent"
    names.append(name)
websitesdf["Name"] = names
websitesdf["Subdir"] = subdirs
websitesdf
# Out:
#          Dataset                                                Url  \
# 0    Comparateur                https://www.10meilleuresbanques.fr/
# 1         Bourse                         https://www.abcbourse.com/
# 2    Institution                     https://acpr.banque-france.fr/
# 3      Assurance                               https://www.afer.fr/
# 4      Assurance                     https://www.ag2rlamondiale.fr/
# ..           ...                                                ...
# 140       Presse  https://www.ouest-france.fr/economie/banques-f...
# 141       Banque                     https://www.revolut.com/fr-FR/
# 142  Institution  https://www.service-public.fr/particuliers/vos...
# 143       Crédit                   https://www.younited-credit.com/
# 144       Bourse                        https://www.zonebourse.com/
#
#          Scope                                               Path  \
# 0       domain  D:\Laurent\nlptextdoc-data-201909\10meilleures...
# 1       domain    D:\Laurent\nlptextdoc-data-201909\abcbourse.com
# 2    subdomain  D:\Laurent\nlptextdoc-data-201909\acpr.banque-...
# 3       domain          D:\Laurent\nlptextdoc-data-201909\afer.fr
# 4       domain  D:\Laurent\nlptextdoc-data-201909\ag2rlamondia...
# ..         ...                                                ...
# 140  subdomain  D:\Laurent\nlptextdoc-data-201909\www.ouest-fr...
# 141       path  D:\Laurent\nlptextdoc-data-201909\www.revolut....
# 142  subdomain  D:\Laurent\nlptextdoc-data-201909\www.service-...
# 143     domain  D:\Laurent\nlptextdoc-data-201909\younited-cre...
# 144     domain   D:\Laurent\nlptextdoc-data-201909\zonebourse.com
#
#                     Name                  Subdir
# 0    10meilleuresbanques  10meilleuresbanques.fr
# 1              abcbourse           abcbourse.com
# 2     acpr-banque-france   acpr.banque-france.fr
# 3                   afer                 afer.fr
# 4         ag2rlamondiale       ag2rlamondiale.fr
# ..                   ...                     ...
# 140         ouest-france     www.ouest-france.fr
# 141              revolut  www.revolut.com_fr-FR_
# 142       service-public   www.service-public.fr
# 143      younited-credit     younited-credit.com
# 144           zonebourse          zonebourse.com
#
# [145 rows x 6 columns]

# %%
websitesdf.drop(columns="Path",inplace=True)
websitesdf
# Out:
#          Dataset                                                Url  \
# 0    Comparateur                https://www.10meilleuresbanques.fr/
# 1         Bourse                         https://www.abcbourse.com/
# 2    Institution                     https://acpr.banque-france.fr/
# 3      Assurance                               https://www.afer.fr/
# 4      Assurance                     https://www.ag2rlamondiale.fr/
# ..           ...                                                ...
# 140       Presse  https://www.ouest-france.fr/economie/banques-f...
# 141       Banque                     https://www.revolut.com/fr-FR/
# 142  Institution  https://www.service-public.fr/particuliers/vos...
# 143       Crédit                   https://www.younited-credit.com/
# 144       Bourse                        https://www.zonebourse.com/
#
#          Scope                 Name                  Subdir
# 0       domain  10meilleuresbanques  10meilleuresbanques.fr
# 1       domain            abcbourse           abcbourse.com
# 2    subdomain   acpr-banque-france   acpr.banque-france.fr
# 3       domain                 afer                 afer.fr
# 4       domain       ag2rlamondiale       ag2rlamondiale.fr
# ..         ...                  ...                     ...
# 140  subdomain         ouest-france     www.ouest-france.fr
# 141       path              revolut  www.revolut.com_fr-FR_
# 142  subdomain       service-public   www.service-public.fr
# 143     domain      younited-credit     younited-credit.com
# 144     domain           zonebourse          zonebourse.com
#
# [145 rows x 5 columns]

# %%
websitesdf.to_csv(rootdir / "_nlptextdoc" / "websites.csv",sep=';')

# %%
targetdir = Path("/mnt/d/Users/Laurent/OneDrive/Dev/Python/nlptextdoc/dataset 092019/extraction")

# %%
import shutil

for idx,row in websitesdf.iterrows():
    name = row[3]
    subdir = row[4]
    source1 = rootdir / subdir / "_nlptextdoc" / "nlptextdocs.dataframe.feather"
    source2 = rootdir / subdir / "_nlptextdoc" / "urls.dataframe.feather"    
    if(not source1.exists()):
        print("ERROR: " + source1)
        continue
    #shutil.copyfile(source1, targetdir / (name + ".nlptextdocs.dataframe.feather"))
    shutil.copyfile(source2, targetdir / (name + ".urls.dataframe.feather"))
    print(name + " copy OK")
# Out:
# 10meilleuresbanques copy OK
# abcbourse copy OK
# acpr-banque-france copy OK
# afer copy OK
# ag2rlamondiale copy OK
# agpm copy OK
# amaguiz copy OK
# arkea copy OK
# assurland copy OK
# aviva copy OK
# axa copy OK
# banque-edel copy OK
# banque-france copy OK
# banque-info copy OK
# banque-fr copy OK
# banquepopulaire copy OK
# banquesenligne copy OK
# bforbank copy OK
# boursedeparis copy OK
# boursedirect copy OK
# boursier copy OK
# boursorama-banque copy OK
# boursorama copy OK
# bred copy OK
# ca-alsace-vosges copy OK
# capitaine-epargne copy OK
# cercledelepargne copy OK
# cetelem copy OK
# cic copy OK
# cnp copy OK
# cofidis copy OK
# cofinoga copy OK
# comparabanques copy OK
# comparalivrets copy OK
# compte-nickel copy OK
# credit-cooperatif copy OK
# credit-du-nord copy OK
# creditmutuel copy OK
# culturebanque copy OK
# diac copy OK
# direct-assurance copy OK
# droit-finances-commentcamarche copy OK
# eko-by-ca copy OK
# empruntis copy OK
# en-bourse copy OK
# eurofil copy OK
# ffa-assurance copy OK
# fortuneo copy OK
# forum-doctissimo copy OK
# forum-doctissimo-2 copy OK
# forum-doctissimo-3 copy OK
# forum-lesarnaques copy OK
# forum-lesarnaques-2 copy OK
# fr-finance-yahoo copy OK
# fr-wikipedia copy OK
# francetransactions copy OK
# generali copy OK
# groupama copy OK
# guide-epargne copy OK
# hellobank copy OK
# hsbc copy OK
# ing copy OK
# labanquepostale copy OK
# labourseauquotidien copy OK
# latribune copy OK
# lcl copy OK
# lelynx copy OK
# lesclesdelabanque copy OK
# lesfurets copy OK
# lolivier copy OK
# mabanque-bnpparibas copy OK
# mae copy OK
# malakoffmederic copy OK
# matmut copy OK
# banque-meilleurtaux copy OK
# mes-placements copy OK
# mma copy OK
# mon-epargne copy OK
# monabanq copy OK
# n26 copy OK
# natixis copy OK
# oney copy OK
# epargne-ooreka copy OK
# orangebank copy OK
# palatine copy OK
# panorabanques copy OK
# probtp copy OK
# psabanque copy OK
# quechoisir copy OK
# retraiteepargne copy OK
# revue-banque copy OK
# smc copy OK
# societegenerale copy OK
# sofinco copy OK
# strategie-bourse copy OK
# toutsurmesfinances copy OK
# tradingsat copy OK
# usine-digitale copy OK
# dumps-wikimedia copy OK
# dumps-wikimedia-2 copy OK
# dumps-wikimedia-3 copy OK
# dumps-wikimedia-4 copy OK
# dumps-wikimedia-5 copy OK
# dumps-wikimedia-6 copy OK
# 60millions-mag copy OK
# allianz copy OK
# allianzbanque copy OK
# ameli copy OK
# amundi copy OK
# assurances copy OK
# banque-org copy OK
# boursorama-forum copy OK
# caisse-epargne copy OK
# cbanque copy OK
# cbanque-forum copy OK
# challenges copy OK
# challenges-2 copy OK
# challenges-3 copy OK
# challenges-4 copy OK
# challenges-5 copy OK
# credit-agricole copy OK
# credit-et-banque copy OK
# creditfoncier copy OK
# economie-gouv copy OK
# gan copy OK
# impots-gouv copy OK
# lefigaro copy OK
# lemonde copy OK
# leparisien copy OK
# lerevenu copy OK
# lesechos copy OK
# lesechos-2 copy OK
# lesechos-3 copy OK
# lesechos-4 copy OK
# lesechos-5 copy OK
# lesechos-6 copy OK
# linternaute-argent copy OK
# maif copy OK
# montepaschi-banque copy OK
# msn copy OK
# ouest-france copy OK
# revolut copy OK
# service-public copy OK
# younited-credit copy OK
# zonebourse copy OK
